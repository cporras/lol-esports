# %% [markdown]
# **Análisis multivariado - LoL e-sports**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',200)

# %%
url_teams = 'https://raw.githubusercontent.com/cporras/lol-esports/main/Data/df_teams.csv'
df = pd.read_csv(url_teams)
df.drop(['position','player','champion','game','date','teamkills','teamdeaths','firstbloodkill','firstbloodassist','firstbloodvictim','turretplates','opp_turretplates','heralds','opp_heralds'],axis=1,inplace=True)
df['quadrakills'] = df['quadrakills'].fillna(0) 
df['pentakills'] = df['pentakills'].fillna(0)

# %%
features = ['result','gamelength','kills','deaths','assists','doublekills','triplekills','quadrakills','pentakills','firstblood','team kpm','ckpm','firstdragon','dragons','opp_dragons','firstherald','firstbaron','barons','opp_barons','firsttower','towers','opp_towers','firstmidtower','firsttothreetowers','inhibitors','opp_inhibitors','damagetochampions','dpm','damagetakenperminute','wardsplaced','wpm','wardskilled','wcpm','controlwardsbought','totalgold','earned gpm','goldspent','total cs','minionkills','monsterkills','monsterkillsownjungle','monsterkillsenemyjungle','cspm','goldat10','xpat10','csat10','golddiffat10','xpdiffat10','csdiffat10','killsat10','assistsat10','deathsat10','opp_killsat10','opp_assistsat10','opp_deathsat10','goldat15','xpat15','csat15','golddiffat15','xpdiffat15','csdiffat15','killsat15','assistsat15','deathsat15','opp_killsat15','opp_assistsat15','opp_deathsat15']
df_feat =  df[features]
df_feat.head()
# Out:
#    result  gamelength  kills  deaths  assists  doublekills  triplekills  \
# 0       0        2050      3       9        6          0.0          0.0
# 1       1        2050      9       3       28          1.0          0.0
# 2       0        2241     16      27       27          2.0          0.0
# 3       1        2241     27      17       59          6.0          1.0
# 4       0        1887      4      15        9          0.0          0.0
#
#    quadrakills  pentakills  firstblood  team kpm    ckpm  firstdragon  \
# 0          0.0         0.0         1.0    0.0878  0.3512          1.0
# 1          0.0         0.0         0.0    0.2634  0.3512          0.0
# 2          0.0         0.0         0.0    0.4284  1.1513          0.0
# 3          0.0         0.0         1.0    0.7229  1.1513          1.0
# 4          0.0         0.0         1.0    0.1272  0.6041          1.0
#
#    dragons  opp_dragons  firstherald  firstbaron  barons  opp_barons  \
# ...

# %% [markdown]
# **Estadisticas por columnas**

# %%
df.describe().T
# Out:
#                            count          mean           std          min  \
# year                      5868.0   2021.000000      0.000000  2021.000000
# playoffs                  5868.0      0.073620      0.261173     0.000000
# game                      5868.0      1.838446      0.809317     1.000000
# patch                     5868.0     11.083865      0.053297    11.010000
# playerid                  5868.0     29.583333     57.655380     1.000000
# gamelength                5868.0   2007.190184    346.466961  1276.000000
# result                    5868.0      0.500000      0.500043     0.000000
# kills                     5868.0      4.013292      4.933493     0.000000
# deaths                    5868.0      4.022154      4.705058     0.000000
# assists                   5868.0      9.230061     11.105990     0.000000
# teamkills                 5868.0     12.039877      6.347323     0.000000
# teamdeaths                5868.0     12.066462      6.333228     0.000000
# ...

# %%
# %matplotlib inline

# %%
#FacetGrid - teamkills vs golddiffat10
sns.FacetGrid(df,hue = 'result' , size = 5).map(plt.scatter,'teamkills','golddiffat10').add_legend();
plt.show()

#Se observa cierta diferencia entre victorias y derrotas para los datos de asesinatos por equipos y diferencia de oro a los 10 minutos, pero igual se evidencia un fuerte solapamiento entre datos
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#FacetGrid - teamkills vs teamdeaths
sns.FacetGrid(df,hue = 'result' , size = 5).map(plt.scatter,'teamkills','teamdeaths').add_legend();
plt.show()

#Si comparamos por otro lado asesinados vs muertes por equipo se pueden separar más facilmente las victorias de las derrotas
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#FacetGrid - teamkills vs teamdeaths
dt_teams = df.groupby('team').mean()
sns.FacetGrid(dt_teams,hue = 'result' , size = 5).map(plt.scatter,'dragons','heralds').add_legend();
plt.show()

#No es muy bueno el grafico elegico, pero se alcanza a ver cierta correlación linea entre cantidad de dragones, herlados y el resultado de una partida
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(df,col='dragons',height=4,hue='dragons')
g.map(sns.scatterplot,'teamkills','teamdeaths')

plt.show()
#Entre más dragones un equipo suele tener más asesinatos y menos muertes

# %%
sns.boxplot(x="result", y="dragons", data=df)

# %%
sns.boxplot(x="result", y="heralds", data=df)

# %%
df[['result','teamdeaths','teamkills','dragons','heralds']].boxplot(by="result", figsize=(12, 6))

#Se espera una relación inversa entre teamdeaths y teamkills
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f754801f790>,
# ...
#       dtype=object)

# %%
df_2 = df[['result','team','teamdeaths','teamkills','dragons','heralds','towers','team kpm']]
sns.pairplot(df_2,hue = 'result' , size = 3 , palette = 'Set2')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
